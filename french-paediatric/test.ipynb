# %%
# !kedro run
# Out:
# [12/26/23 11:07:25] INFO     Kedro project paediatric_data       session.py:364
# Filepath: ...
# sftp://193.218.11.199/upload/Test_Data/pediatric_data/AIOLOS19-12-2023.xlsx
# ┌───────────────────── Traceback (most recent call last) ─────────────────────┐
# │ C:\Users\tfauvel\.conda\envs\kedro-environment\lib\site-packages\kedro\io\c │
# │ ore.py:161 in from_config                                                   │
# │                                                                             │
# │ C:\Users\tfauvel\Downloads\paediatric_data\src\paediatric_data_processing\e │
# │ xtras\datasets\sftp_dataset.py:66 in __init__                               │
# │                                                                             │
# │    63 │   │   print("Filepath: ...")                                        │
# │    64 │   │   print(filepath)                                               │
# │    65 │   │                                                                 │
# ...

# %%
from src.paediatric_data_processing.extras.datasets.mongodb_dataset import MongoDBDataSet

# %%
import sys 
sys.path.insert(0, ".")
 
from src.paediatric_data_processing.extras.datasets.mongodb_dataset import MongoDBDataSet

# %%
# !kedro run --env=dev --docker-args="--env AWS_ACCESS_KEY_ID="AKIA3EYHIGTO4PRWJNJT" --env AWS_SECRET_ACCESS_KEY="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" --env MongoDBUsername="QuintenPipelineUser" --env MongoDBPassword="PDb6uqwogle8sYFL" --env CGM_PASSWORD="cmxJwnSmzPnQa55""

# %%
# !kedro docker run --env=dev --docker-args="--env AWS_ACCESS_KEY_ID="AKIA3EYHIGTO4PRWJNJT" --env AWS_SECRET_ACCESS_KEY="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" --env MongoDBUsername="QuintenPipelineUser" --env MongoDBPassword="PDb6uqwogle8sYFL" --env CGM_PASSWORD="cmxJwnSmzPnQa55""
# Out:
# docker run -v 'C:\Users\tfauvel\Downloads\paediatric_data\conf\local:/home/kedro_docker/conf/local' -v 'C:\Users\tfauvel\Downloads\paediatric_data\data:/home/kedro_docker/data' -v 'C:\Users\tfauvel\Downloads\paediatric_data\logs:/home/kedro_docker/logs' -v 'C:\Users\tfauvel\Downloads\paediatric_data\notebooks:/home/kedro_docker/notebooks' -v 'C:\Users\tfauvel\Downloads\paediatric_data\references:/home/kedro_docker/references' -v 'C:\Users\tfauvel\Downloads\paediatric_data\results:/home/kedro_docker/results' --rm --name paediatric_data-run --env AWS_ACCESS_KEY_ID=AKIA3EYHIGTO4PRWJNJT --env AWS_SECRET_ACCESS_KEY=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 --env MongoDBUsername=QuintenPipelineUser --env MongoDBPassword=PDb6uqwogle8sYFL --env CGM_PASSWORD=cmxJwnSmzPnQa55 paediatric_data kedro run --env=dev
# [12/26/23 09:22:44] WARNING  /usr/local/lib/python3.10/site-pack warnings.py:109
#                              ages/kedro_datasets/json/json_datas
# ...

# %%
import kedro
kedro.__version__
# Out:
# '0.19.1'

# %%
import kedro_datasets
kedro_datasets.__version__
# Out:
# '2.0.0'
